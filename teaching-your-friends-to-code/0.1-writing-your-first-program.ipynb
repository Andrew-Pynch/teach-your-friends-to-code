# %% [markdown]
# # Writing Your First Program
# Before we begin, I must make clear the MOST important truth required to be a successful software engineer (at least in my opinion). The most successful software engineers I have encountered are constantly building, and learning by building.
#
# I stronly recommend that at each step of this book, you physically type in the code yourself, and run it to compare against the results we
# produce here.

# %% [markdown]
# # Hello World
# The first program we will write, is the program everyone starts with! Hello world in Python. For all of these examples, we will be using the Python interpreter. The interpreter is a program that reads your code, and executes it.
#
# For all examples in this book you will see a code block, followed by the result of running the code block. Notice below, the code for print('hello world') followed by the output from the program.

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # Writing and running your own code
# To write your own code, you will need to open a text editor. On Windows, you can use Notepad, or Notepad++. On Mac, you can use TextEdit, or TextWrangler. On Linux, you can use gedit, or vim.
